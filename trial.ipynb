# %% [markdown]
# ## Library import

# %%
import os
import itertools
from random import randint
import numpy as np
import pandas as pd
import librosa
import torch 
import torch.utils.data as data
import torchvision.transforms as transforms
import lightning as L

# %% [markdown]
# ## Establishing folder structure for dataset
# data_split -> sub -> audio_material -> type_of_file.

# %%
file_ext = "*.npy"

# %%
file_list = glob.glob(os.path.join(dir_pth, file_ext))

# %%
def data_segmentation(fpath : str):
  fname = (fpath.split("/")[-1])
  file_seg = (fpath.split("/")[-1]).split("_-_")[0]
  print(fname)

  # creating sub-dirs : train, val and test
  for seg in ["train", "val", "test"]:
    sub_dir = os.path.join(dir_pth, seg)
    if not os.path.exists(sub_dir):
      os.makedirs(sub_dir)

  # moving file to desired segment folder
  src_file = fpath
  dest_file = os.path.join(dir_pth, file_seg, fname)
  shutil.move(src_file, dest_file)

  # Check if the file has been moved
  if os.path.exists(dest_file):
    print(f"File has been moved to : {dest_file}")
  else:
    print("File move operation failed")

# %%
for f in file_list:
  data_segmentation(f)
# Out:
# File has been moved to : /media/kunal/Ubuntu/data/eeg_data/split_data/test/test_-_sub-002_-_audiobook_2_1_-_mel.npy
# test_-_sub-002_-_audiobook_5_2_-_eeg.npy
# File has been moved to : /media/kunal/Ubuntu/data/eeg_data/split_data/test/test_-_sub-002_-_audiobook_5_2_-_eeg.npy
# test_-_sub-003_-_audiobook_1_-_mel.npy
# File has been moved to : /media/kunal/Ubuntu/data/eeg_data/split_data/test/test_-_sub-003_-_audiobook_1_-_mel.npy
# test_-_sub-003_-_audiobook_5_2_-_mel.npy
# File has been moved to : /media/kunal/Ubuntu/data/eeg_data/split_data/test/test_-_sub-003_-_audiobook_5_2_-_mel.npy
# test_-_sub-004_-_audiobook_2_2_-_envelope.npy
# File has been moved to : /media/kunal/Ubuntu/data/eeg_data/split_data/test/test_-_sub-004_-_audiobook_2_2_-_envelope.npy
# test_-_sub-005_-_audiobook_5_1_-_eeg.npy
# File has been moved to : /media/kunal/Ubuntu/data/eeg_data/split_data/test/test_-_sub-005_-_audiobook_5_1_-_eeg.npy
# test_-_sub-006_-_audiobook_2_1_-_mel.npy
# File has been moved to : /media/kunal/Ubuntu/data/eeg_data/split_data/test/test_-_sub-006_-_audiobook_2_1_-_mel.npy
# test_-_sub-006_-_audiobook_5_3_-_envelope.npy
# File has been moved to : /media/kunal/Ubuntu/data/eeg_data/split_data/test/test_-_sub-006_-_audiobook_5_3_-_envelope.npy
# test_-_sub-007_-_audiobook_2_1_-_envelope.npy
# File has been moved to : /media/kunal/Ubuntu/data/eeg_data/split_data/test/test_-_sub-007_-_audiobook_2_1_-_envelope.npy
# test_-_sub-007_-_audiobook_6_1_-_eeg.npy
# File has been moved to : /media/kunal/Ubuntu/data/eeg_data/split_data/test/test_-_sub-007_-_audiobook_6_1_-_eeg.npy
# test_-_sub-028_-_audiobook_7_3_-_envelope.npy
# File has been moved to : /media/kunal/Ubuntu/data/eeg_data/split_data/test/test_-_sub-028_-_audiobook_7_3_-_envelope.npy
# test_-_sub-028_-_audiobook_7_3_-_mel.npy
# File has been moved to : /media/kunal/Ubuntu/data/eeg_data/split_data/test/test_-_sub-028_-_audiobook_7_3_-_mel.npy
# test_-_sub-028_-_audiobook_7_4_-_eeg.npy
# File has been moved to : /media/kunal/Ubuntu/data/eeg_data/split_data/test/test_-_sub-028_-_audiobook_7_4_-_eeg.npy
# test_-_sub-028_-_audiobook_7_4_-_envelope.npy
# File has been moved to : /media/kunal/Ubuntu/data/eeg_data/split_data/test/test_-_sub-028_-_audiobook_7_4_-_envelope.npy
# test_-_sub-028_-_audiobook_7_4_-_mel.npy
# File has been moved to : /media/kunal/Ubuntu/data/eeg_data/split_data/test/test_-_sub-028_-_audiobook_7_4_-_mel.npy
# test_-_sub-028_-_audiobook_7_5_-_eeg.npy
# File has been moved to : /media/kunal/Ubuntu/data/eeg_data/split_data/test/test_-_sub-028_-_audiobook_7_5_-_eeg.npy
# test_-_sub-028_-_audiobook_7_5_-_envelope.npy
# File has been moved to : /media/kunal/Ubuntu/data/eeg_data/split_data/test/test_-_sub-028_-_audiobook_7_5_-_envelope.npy
# test_-_sub-028_-_audiobook_7_5_-_mel.npy
# File has been moved to : /media/kunal/Ubuntu/data/eeg_data/split_data/test/test_-_sub-028_-_audiobook_7_5_-_mel.npy
# test_-_sub-028_-_audiobook_7_6_-_eeg.npy
# File has been moved to : /media/kunal/Ubuntu/data/eeg_data/split_data/test/test_-_sub-028_-_audiobook_7_6_-_eeg.npy
# test_-_sub-028_-_audiobook_7_6_-_envelope.npy
# File has been moved to : /media/kunal/Ubuntu/data/eeg_data/split_data/test/test_-_sub-028_-_audiobook_7_6_-_envelope.npy
# test_-_sub-028_-_audiobook_7_6_-_mel.npy
# File has been moved to : /media/kunal/Ubuntu/data/eeg_data/split_data/test/test_-_sub-028_-_audiobook_7_6_-_mel.npy
# test_-_sub-028_-_podcast_10_-_eeg.npy
# File has been moved to : /media/kunal/Ubuntu/data/eeg_data/split_data/test/test_-_sub-028_-_podcast_10_-_eeg.npy
# test_-_sub-028_-_podcast_10_-_envelope.npy
# File has been moved to : /media/kunal/Ubuntu/data/eeg_data/split_data/test/test_-_sub-028_-_podcast_10_-_envelope.npy
# test_-_sub-028_-_podcast_10_-_mel.npy
# File has been moved to : /media/kunal/Ubuntu/data/eeg_data/split_data/test/test_-_sub-028_-_podcast_10_-_mel.npy
# test_-_sub-028_-_podcast_1_-_eeg.npy
# File has been moved to : /media/kunal/Ubuntu/data/eeg_data/split_data/test/test_-_sub-028_-_podcast_1_-_eeg.npy
# test_-_sub-028_-_podcast_1_-_envelope.npy
# File has been moved to : /media/kunal/Ubuntu/data/eeg_data/split_data/test/test_-_sub-028_-
2_-_mel.npy
# File has been moved to : /media/kunal/Ubuntu/data/eeg_data/split_data/test/test_-_sub-082_-_audiobook_14_2_-_mel.npy
# test_-_sub-082_-_audiobook_1_-_eeg.npy
# File has been moved to : /media/kunal/Ubuntu/data/eeg_data/split_data/test/test_-_sub-082_-_audiobook_1_-_eeg.npy
# test_-_sub-082_-_audiobook_1_-_envelope.npy
# File has been moved to : /media/kunal/Ubuntu/data/eeg_data/split_data/test/test_-_sub-082_-_audiobook_1_-_envelope.npy
# test_-_sub-082_-_audiobook_1_-_mel.npy
# File has been moved to : /media/kunal/Ubuntu/data/eeg_data/split_data/test/test_-_sub-082_-_audiobook_1_-_mel.npy
# test_-_sub-082_-_podcast_35_-_eeg.npy
# File has been moved to : /media/kunal/Ubuntu/data/eeg_data/split_data/test/test_-_sub-082_-_podcast_35_-_eeg.npy
# test_-_sub-082_-_podcast_35_-_envelope.npy
# File has been moved to : /media/kunal/Ubuntu/data/eeg_data/split_data/test/test_-_sub-082_-_podcast_35_-_envelope.npy
# test_-_sub-082_-_podcast_35_-_mel.npy
# File has been moved to : /media/kunal/Ubuntu/data/eeg_data/split_data/test/test_-_sub-082_-_podcast_35_-_mel.npy
# train_-_sub-026_-_audiobook_3_-_mel.npy
# File has been moved to : /media/kunal/Ubuntu/data/eeg_data/split_data/train/train_-_sub-026_-_audiobook_3_-_mel.npy
# train_-_sub-026_-_audiobook_4_-_eeg.npy
# File has been moved to : /media/kunal/Ubuntu/data/eeg_data/split_data/train/train_-_sub-026_-_audiobook_4_-_eeg.npy
# train_-_sub-026_-_audiobook_4_-_envelope.npy
# File has been moved to : /media/kunal/Ubuntu/data/eeg_data/split_data/train/train_-_sub-026_-_audiobook_4_-_envelope.npy
# train_-_sub-026_-_audiobook_4_-_mel.npy
# File has been moved to : /media/kunal/Ubuntu/data/eeg_data/split_data/train/train_-_sub-026_-_audiobook_4_-_mel.npy
# train_-_sub-026_-_audiobook_5_1_-_eeg.npy
# File has been moved to : /media/kunal/Ubuntu/data/eeg_data/split_data/train/train_-_sub-026_-_audiobook_5_1_-_eeg.npy
# train_-_sub-026_-_audiobook_5_1_-_envelope.npy
# File has been moved to : /media/kunal/Ubuntu/data/eeg_data/split_data/train/train_-_sub-026_-_audiobook_5_1_-_envelope.npy
# train_-_sub-026_-_audiobook_5_1_-_mel.npy
# File has been moved to : /media/kunal/Ubuntu/data/eeg_data/split_data/train/train_-_sub-026_-_audiobook_5_1_-_mel.npy
# train_-_sub-026_-_audiobook_5_2_-_eeg.npy
# File has been moved to : /media/kunal/Ubuntu/data/eeg_data/split_data/train/train_-_sub-026_-_audiobook_5_2_-_eeg.npy
# train_-_sub-026_-_audiobook_5_2_-_envelope.npy
# File has been moved to : /media/kunal/Ubuntu/data/eeg_data/split_data/train/train_-_sub-026_-_audiobook_5_2_-_envelope.npy
# train_-_sub-026_-_audiobook_5_2_-_mel.npy
# File has been moved to : /media/kunal/Ubuntu/data/eeg_data/split_data/train/train_-_sub-026_-_audiobook_5_2_-_mel.npy
# train_-_sub-026_-_audiobook_5_3_-_eeg.npy
# File has been moved to : /media/kunal/Ubuntu/data/eeg_data/split_data/train/train_-_sub-026_-_audiobook_5_3_-_eeg.npy
# train_-_sub-026_-_audiobook_5_3_-_envelope.npy
# File has been moved to : /media/kunal/Ubuntu/data/eeg_data/split_data/train/train_-_sub-026_-_audiobook_5_3_-_envelope.npy

# %% [markdown]
# ## Data Loader

# %%
dir_pth = '/home/kunal/eeg_data/derivatives/toy_split'

# %%
test_eeg_file_path = '/home/kunal/eeg_data/derivatives/toy_split/test/test_-_sub-001_-_audiobook_1_-_eeg.npy'
test_mel_file_path = '/home/kunal/eeg_data/derivatives/toy_split/test/test_-_sub-001_-_audiobook_1_-_mel.npy'

# %%
def sliding_window(self, x: torch.Tensor) -> torch.Tensor:
        return x.unfold(0, self.frame_length, self.hop_length)

# %%
## test sliding window
try_eeg = torch.from_numpy(np.load(test_eeg_file_path))
try_mel= torch.from_numpy(np.load(test_mel_file_path))
print("EEG: ",)
# Out:
# EEG:

# %% [markdown]
# ### Custom PyTorch Dataset

# %%
class EEGDataset(data.Dataset):
    def __init__(self, files, input_length, channels, task, g_con = True) -> None:
        super().__init__()
        self.input_length = input_length
        self.files = self.group_recordings(files)
        self.channels = channels
        self.task = task
        self.g_con = g_con

    def group_recordings(self, files):
        new_files = []
        grouped = itertools.groupby(sorted(files), lambda x: "_-_".join(os.path.basename(x).split("_-_")[:3]))
        for recording_name, feature_paths in grouped:
            new_files += [sorted(feature_paths, key=lambda x: "0" if x == "eeg" else x)]
        return new_files
        
    def __len__(self):
        return len(self.files)
    
    def __getitem__(self, recording_index):
        if self.task !="test":
            framed_data = []
            for idx, feature in enumerate(self.files[recording_index]):
                data = np.load(feature)
                if idx == 0:
                    start_idx = randint(0, len(data) - self.input_length)
                    
                framed_data += [data[start_idx:start_idx + self.input_length]]
            if self.g_con == True:
                sub_id = feature.split('/')[-1].split('_-_')[1].split('-')[-1]
                sub_id = int(sub_id) - 1
            else:
                sub_id = torch.FloatTensor([0])
            return torch.FloatTensor(framed_data[0]), torch.FloatTensor(framed_data[1])
        else:
            for idx, feature in enumerate(self.files[recording_index]):
                data = np.load(feature)
                nsegment = data.shape[0] // self.input_length
                data = data[:int(nsegment * self.input_length)]
                segment_data = [torch.FloatTensor(data[i:i+self.input_length]).unsqueeze(0) for i in range(0, data.shape[0], self.input_length)]
                segment_data = torch.cat(segment_data)
                framed_data += [segment_data]
            
            if self.g_con == True:
                sub_idx = feature.split('/')[-1].split('_-_')[1].split('-')[-1]
                sub_idx = int(sub_idx) - 1    
    
            else:
                sub_idx = torch.FloatTensor([0])
            return framed_data[0], framed_data[1]

# %% [markdown]
# ### Lightning DataModule

# %%
class RegressionDataModule(L.LightningDataModule):
    def __init__(self, config_path: str, batch_size:int=64, frame_length:int=64, hop_length:int=64) -> None:
        super().__init__()
        with open(config_path) as fp:
            self.config = json.load(fp)
            
        self.data_dir = os.path.join(self.config["dataset_folder"],self.config["derivatives_folder"],  self.config["split_folder"])
        self.features = ["eeg",  "mel"]
        
        self.batch_size = batch_size
        self.frame_length = 64
        self.hop_length = 10

        self.input_length = self.frame_length * self.hop_length
        self.channel = 64
    
    def prepare_data(self):
        # download, IO, etc. Useful with shared filesystems
        # only called on 1 GPU/TPU in distributed
        pass

    def setup(self, stage:str):
        # make assignments here (val/train/test split)
        # called on every process in DDP
        if stage=="fit":
            train_files = [x for x in glob.glob(os.path.join(data_dir, "train", "train_-_*")) if os.path.basename(x).split("_-_")[-1].split(".")[0] in self.features]
            self.train = EEGDataset(files=train_files, input_length=self.input_length, channel=self.channel, task="train", g_con=False)
        if stage == "validate":
            val_files = [x for x in glob.glob(os.path.join(data_dir, "val", "val_-_*")) if os.path.basename(x).split("_-_")[-1].split(".")[0] in self.features]
            self.val = EEGDataset(files=val_files, input_length=self.input_length, channel=self.channel, task="val", g_con=False)
        if stage == "test":
            test_files = [x for x in glob.glob(os.path.join(data_dir, "test", "test_-_*")) if os.path.basename(x).split("_-_")[-1].split(".")[0] in self.features]
            self.test = EEGDataset(files=test_files, input_length=self.input_length, channel=self.channel, task="test", g_con=False)
        if stage == "predict":
           pass
        else:
            pass

    def train_dataloader(self):
        return data.DataLoader(self.train, batch_size=self.batch_size)

    def val_dataloader(self):
        return data.DataLoader(self.val, batch_size=self.batch_size)

    def test_dataloader(self):
        return data.DataLoader(self.test, batch_size=self.batch_size)

    def teardown(self):
        # clean up state after the trainer stops, delete files...
        # called on every process in DDP
        ...

# %%
print(dir_pth)
# Out:
# /home/kunal/eeg_data/derivatives/toy_split

# %%
torch.FloatTensor([0])
# Out:
# tensor([0.])
